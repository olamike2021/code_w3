# %%
x = 10
y = "folorunso"
​
print(x)
print(y)
10
folorunso
 
name, age, pi, bool = "mayowa", 20, 36.14, True
​
print(name, age, pi, bool)
mayowa 20 36.14 
 
z = "agboola"
z = 4
​
print(z)
4
 
x = 5 
x = "carer"
​
print(x)
carer
 
#Variable Names task

myvar = "agboola"
my_var = "folorunso"
_my_var = "emmanuel"
myVAR = "michael"
MYVAR = "cecilia"
myvar2 = "damilola"
 
print(myvar)
print(my_var)
print(_my_var)
print(myVAR)
print(MYVAR)
print(myvar2)
agboola
folorunso
emmanuel
michael
cecilia
damilola

name, full_name, pi = "james", "j james", 3.14
​
print(name, full_name, pi)
james j james 3.14
In [3]:
 
name, full_name, pi = "michael", "A emmanuel", 3.14
​
print(name, full_name, pi)
michael A emmanuel 3.14
 
#Python data type<>(())
 
x = int(6)
y = str(3)
z = float(3)
q = bool
 
print(x)
print(y)
print(z)
print(bool)
6
3
3.0
True
 
c = float(9)
b = int(4)
n = str(12)
In [451]:
 
print(c)
print(b)
print(n)
9.0
4
12
 
y = 10
z = "emmanuel"
 
print(type(y))
print(type(z))
<class 'int'>
<class 'str'>
 
t = 40
q = "school"
 
print(type(t))
print(type(q))
<class 'int'>
<class 'str'>
 
brand = "amigoscode"
age = 23
pi = 3.14 
numbers = []
isAdult = True
 
print(type(brand))
print(type(age))
print(type(pi))
print(type(numbers))
print(type(isAdult))
<class 'str'>
<class 'int'>
<class 'float'>
<class 'list'>
<class 'bool'>
 
k = 50
u = "cottbus"
r = 30.56
 
print(type(k))
print(type(u))
print(type(r))
<class 'int'>
<class 'str'>
<class 'float'>
 
#Case-Sensitive<>Variable names are case-sensitive.This will create two variables:

m = 8
M = "damilola"
 
print(M)
print(m)
damilola
8
 
u = 9
Q = "willi_budich"
 
print(u)
print(Q)
9
willi_budich
 
#Many Values to Multiple Variables task
 
x, y, z, f = "grape", "apple", "banana", "blue_berry"

print(x)
print(y)
print(z)
print(f)
grape
apple
banana
blue_berry
 
l, v, d, w = "orange", "melon", "blue_berry", "mango"
 
print(l)
print(v)
print(d)
print(w)
orange
melon
blue_berry
mango
 
#One Value to Multiple Variables
 
k = l = w = "cherry"
 
print(k)
print(l)
print(w)
cherry
cherry
cherry
 
r = t = q = j = "avocado"
 
print(r)
print(t)
print(q)
print(j)
avocado
avocado
avocado
avocado
 
#Unpack a Collection inside the list
 
fruits = ["melon", "cherry_wood", "banana"]
y, z, x = fruits
 
print(y)
print(z)
print(x)
melon
cherry_wood
banana
 
foods = ["rice", "eba", "beans","yam","garri","spaghetti","indomine"]
w, s, q, v, t, g, n, = foods

 
print(w)
print(s)
print(q)
print(v)
print(t)
print(g)
print(n)
rice
eba
beans
yam
garri
spaghetti
indomine
 
brands = ["tommy", "gucci", "zara", "all_star", "nike", "mango", "iphone", "Samsung"]
t, i, v, b, n, k, m, f = brands
 
print(t)
print(i)
print(v)
print(b)
print(n)
print(k)
print(m)
print(f)
tommy
gucci
zara
all_star
nike
mango
iphone
Samsung
 
#Python - Output Variables
 
y = "folorunso is awesome"
 
print(y)
folorunso is awesome
 
z = "python"
x = "is"
y = "awesome"
p = "love"
k = "rootings"
 
print(z, x, y, p, k,)
python is awesome love rootings
 
y = "python "
z = "is "
x = "awesome "
g = "favourite "
h = "matters "
s = "sweet "
 
print(y + z + x + g + h + s)
python is awesome favourite matters sweet 
 
y = 10
x = 90
In [40]:
 
print(y + x)
100
 
v = 1000
m = 4500
 
print(v + m)
5500
 
w = 5000
s = 50
print(w * s)
250000
 
z = 24
y = "folorunso"
 
print(z , y)
24 folorunso
 
a = 33
j = "emmanuel"
 
print(a , j)
33 emmanuel
 
#Python - Global Variables
In [88]:
 
x = "awesome"
​
def myfunc():
    print("python is " + x)
​
myfunc()
python is awesome
 
z = "awesome"
​
def myfunc():
    z = "fantastic"
    print("python is " + z)
    
myfunc()
​
print("python is " + z)
python is fantastic
python is awesome
 
def myfunc():
    global x
    x = "fantastic"
    
myfunc()
​
print("python is " + x)
python is fantastic
 
x = "awesome"
​
def myfunc():
    global x
    x = "fantastic"
    
myfunc()
​
print("python is " + x)
    
python is fantastic
 
x = 1
z = 2.8
y = 1j
 
print(type(x))
print(type(z))
print(type(y))
<class 'int'>
<class 'float'>
<class 'complex'>
 
#Integers:
 
s = 0
x = 1
z = 35656222554887711
y = -3255522

print(type(s))
print(type(x))
print(type(z))
print(type(y))
<class 'int'>
<class 'int'>
<class 'int'>
<class 'int'>

#Float<>Float, or "floating point number" is a number, positive or negative, containing one or more decimals.
 
y = 1.10
x = 1.0
z = -35.59
 
print(type(y))
print(type(x))
print(type(z))

<class 'float'>
<class 'float'>
<class 'float'>
 
#float<>Float can also be scientific numbers with an "e" to indicate the power of 10.
In [98]:
 
x = 35e3
z = 12E4
y = -87.7e100
In [99]:
 
print(type(x))
print(type(z))
print(type(y))
<class 'float'>
<class 'float'>
<class 'float'>
In [4]:
z = 45e6
​
print(type(z))
<class 'float'>
 
y = 12E8
​
print(type(y))
<class 'float'>
 
#Complex<>Complex numbers are written with a "j" as the imaginary part:
 
z = 3+5j
x = 5j
y = -5j
 
print(type(z))
print(type(x))
print(type(y))
<class 'complex'>
<class 'complex'>
<class 'complex'>
 
#Type Conversion
 
x = float(1)
​
y = int(2.8)
​
z = complex(1)
 
print(x)
print(y)
print(z)
1.0
2
(1+0j)
 
print(type(x))
print(type(y))
print(type(z))
<class 'int'>
<class 'int'>
<class 'float'>
 
q = complex(10)
​
s = float(7000)
​
g = int(36.13)
 
print(q)
print(s)
print(g)
(10+0j)
7000.0
36
 
print(type(q))
print(type(s))
print(type(g))
<class 'complex'>
<class 'float'>
<class 'int'>
 
z = float(30.44)
print(int(z))
30
 
y = int(5000)
print(float(y))
5000.0
 
x = (9)
print(complex(x))
(9+0j)
 
#Random Number<>Python does not have a random() function to make a random number, but Python has a built-in module called random that can be used to make random numbers:
 
import random
​
print(random.randrange(1, 9))
8
 
import random
​
print(random.randrange(2, 8))
7
 
import random
​
print(random.randrange(5, 20))
15
 
#Python Casting<>intergers
 
y = int(1)
x = int(2.8)
z = int("3")
g = int(0)
​
print(y)
print(x)
print(z)
print(g)
1
2
3
0
 
#Python Casting<>floats
 
y = float(0) 
x = float(1.8)
z = float("3")
w = float("4.2")
​
print(y)
print(x)
print(z)
print(w)
0.0
1.8
3.0
4.2
 
g = float(4)
h = float(4.18)
k = float("16")
l = float("28.8")
​
print(g)
print(h)
print(k)
print(l)
4.0
4.18
16.0
28.8
 
#Python Casting<>strings
 
x = str("s1")
z = str(2)
y = str(3.0)
​
print(x)
print(z)
print(y)
s1
2
3.0
 
o = ("s10")
b = (18)
f = (6.0)
​
print(o)
print(b)
print(f)
s10
18
6.0
 
#Strings are Arrays<>
 
a = "Hello, world!"
​
print(a[4])
print(a[11])
print(a[9])
o
d
r
 
x = "good, morning!"
​
print(x[3])
print(x[2])
print(x[6])
d
o
m
In [9]:
import array as arr 
​
numbers = ('i', [10, 20, 30])
​
print(numbers)
('i', [10, 20, 30])
 
from array import *
​
numbers = ('d', [10.0, 20.0, 30.0])
​
print(numbers)
('d', [10.0, 20.0, 30.0])

import array as arr
​
numbers = arr.array('q',[10,20,30])
​
print(numbers[:2])
print(numbers[-2:])
array('q', [10, 20])
array('q', [20, 30])
In [23]:
import array as arr 
​
numbers = arr.array('i',[10,20,30,40,50,60,70,80,90])
​
print(numbers[:-6])
​
array('i', [10, 20, 30])
 
brand = "amigoscode"
​
print(brand)
amigoscode
 
brand = "Amigoscode"
​
print(brand.replace("A", "a"))
print(brand.replace("A", "40"))
print(len(brand))
print(brand == "Amigoscode")
print(brand == "amigoscode")
print(brand != "amigoscode")
print("code" in brand)
print("code" not in brand)
amigoscode
40 migoscode
10
True
False
True
True
False
 
x = "Good, morning!"
 
print(x[12])
g
 
z = "cottbus_train_station!"
 
print(z[20])
n

#Looping Through a String<>Since strings are arrays, we can loop through the characters in a string, with a for loop.
 
for x in "banana":
  print(x)
b
a
n
a
n
a
 
for z in "school":
    print(z)
s
c
h
o
o
l
 
for y in "education":
    print(y)
e
d
u
c
a
t
i
o
n 
 
#String Length<>To get the length of a string, use the len() function.
 
a = "Hello, world!"
 
print(len(a))
13
 
z = "cottbus_train_station!"
 
print(len(z))
22
 
brand = "amigoscode"
 
print(brand == "amigoscode")
True
 
house = "willi_budich"
 
print(house != "willi_budich")
False
 
city = "Cottbus"
 
print(city != "cottbus")
True
 
#Check String<>To check if a certain phrase or character is present in a string, we can use the keyword in.

txt = "the best things in life is free!"
print("free" in txt)
True
 
py = "the best things to learn in life is python code"
print("code" in py)
True
 
#Use it in an if statement

txt = "the best things to learn in life is python code!"
if "code" in txt:
    print("yes, 'python' is present.")
yes, 'python' is present.

 
name = "my name is michael to the best in this world is to code!"
if "code" in name:
    print("yes, 'micheal' is present.")
yes, 'micheal' is present.
 
#Check if NOT<>To check if a certain phrase or character is NOT present in a string, we can use the keyword not in.
 
#Use it in an if statement:
 
txt = "the best thing in life is free!"
if "expensive" not in txt:
    print("No, 'expensive' is NOT present.")
No, 'expensive' is NOT present.
 
life = "hard things last for ever and ever in human hands!"
if "expensive" not in life:
    print("YES, 'expensive' is NOT present.")
YES, 'expensive' is NOT present.

txtco = "The most of things in life they are not for free!"
if "expensive" not in txtco:
    print("No, 'expensive' is NOT Present.")
    
​
No, 'expensive' is NOT Present.

#Slicing<>You can return a range of characters by using the slice syntax.Specify the start index and the end index, separated by a colon, to return a part of the string.

y = "Hello, world!"
print(y[2:5])
llo

x = "cottbus, station!"
print(x[2:7])
ttbus

z = "Transportion!"
print(z[4:20])
sportion!
 
#Slice From the Start<>By leaving out the start index, the range will start at the first character:Get the characters from the start to position 5 (not included):
 
b = "folorunso!"
print(b[:9])
folorunso
 
p = "cottbus, germany!"
print(p[:7])
cottbus
 
#Slice To the End<>By leaving out the end index, the range will go to the end:Get the characters from position 2, and all the way to the end:

 
b = "Hello, world!"
print(b[3:])
lo, world!
 
v = "determination, mind!"
print(v[5:])
mination, mind!
 
#Negative Indexing<>Use negative indexes to start the slice from the end of the string:Get the characters:From: "o" in "World!" (position -5)To, but not included: "d" in "World!" (position -2):

 
b = "Hello, world!"
print(b[-5:-2])
orl
 
z = "jupyter, python!"
print(z[-5:-2])
tho
 
#Python - Modify Strings<>Python has a set of built-in methods that you can use on strings.Upper Caseyour own Python ServerThe upper() method returns the string in upper case:

 
a = "Hello, world!"
print(a.upper())
HELLO, WORLD!
 
x = "python, code!"
print(x.upper())
PYTHON, CODE!
 
#Lower Case<>The lower() method returns the string in lower case:
 
c = "Hello, jupyter!"
print(c.lower())
hello, jupyter!
 
y = "folorunso, python!"
print(y.lower())
folorunso, python!
 
#Remove Whitespace<>Whitespace is the space before and/or after the actual text, and very often you want to remove this space.The strip() method removes any whitespace from the beginning or the end:

 
a = "Hello, world!"
print(a.strip())
Hello, world!
 
b = "python, code!"
print(b.strip())
python, code!
 
#Replace String<>The replace() method replaces a string with another string:
 
a = "Hello, world!"
print(a.replace("H", "J"))
Jello, world!
 
x = "Python, world!"
print(x.replace("P", "Q"))
Qython, world!
 
y = "Good, morning!"
print(y.replace("G", "L"))
Lood, morning!
 
#split String<>The split() method returns a list where the text between the specified separator becomes the list items.
#The split() method splits the string into substrings if it finds instances of the separator:

a = "Hello, world!"
print(a.split(","))
['Hello', ' world!']
 
x = "python, txt_code!"
print(x.split(","))
['python', ' txt_code!']
 
#String Concatenation<>To concatenate, or combine, two strings you can use the + operator.your own Python Server
#Merge variable a with variable b into variable c:
 
a = "Hello"
b = "world"
c = a + b
print(c)
Helloworld
 
y = "konigs"
z = "cottbus"
x = y + " " + z
print(x)
konigs cottbus
 
#String Format<>As we learned in the Python Variables chapter, we cannot combine strings and numbers like this:
#But we can combine strings and numbers by using the format() method!
#The format() method takes the passed arguments, formats them, and places them in the string where the placeholders {} are:
#Use the format() method to insert numbers into strings:
 
age = 36
txt = "My name is john, and  i am {}"
print(txt.format(age))
My name is john, and  i am 36
 
age = 23
code = "python code is the best, i am interested in {}"
print(code.format(age))
python code is the best, i am interested in 23
 
name = "jamila"
​
email = """
​
hello {},
how are you doing?
it was nice talking to you here
​
"""
print(email.format(name))
hello jamila,
how are you doing?
it was nice talking to you here

name = "Folorunso"
​
email = f""" 
​
blessed morning to you my very good friend {name}, 
nice learing in your homework keep it up bro?
never stop learing your python code everyday bro...
age {10 + 13}!
"""
print(email)
 

blessed morning to you my very good friend Folorunso, 
nice learing in your homework keep it up bro?
never stop learing your python code everyday bro...
age 23!

 
#The format() method takes unlimited number of arguments, and are placed into the respective placeholders:

quntity = 3
itemno = 567
price = 49.95
myorder = " i want {} pieces of item {} for {} dollars."
print(myorder.format(quntity, itemno, price))
 i want 3 pieces of item 567 for 49.95 dollars.

high_level = 15
seria_number = 1876
price = 200.99
checkout = "i want {} pieces of nivea_body_cream {} for {} euros."
print(checkout.format(high_level, seria_number, price))
i want 15 pieces of nivea_body_cream 1876 for 200.99 euros.
 
#You can use index numbers {0} to be sure the arguments are placed in the correct placeholders:
 
quntity = 3 
itemno = 567
price = 450.98
my_order_is = "i want pay {2} pounds for {4} piece of Chocolate_milkshake {7}."
print(myorder.format(quntity, itemno, price))
 i wait 3 pieces of item 567 for 450.98 dollars.
 
quntity = 20
itemno = 567
price = 49.95
my_order_is = "i want to pay {2} dollars for {3} piece of justice_enegry_drinks {5}."
print(myorder.format(quntity, itemno, price))
 i want 20 pieces of item 567 for 49.95 dollars.
 
#Python - Escape Characters<> To insert characters that are illegal in a string, use an escape character.
#An escape character is a backslash (\" \") followed by the character you want to insert.
#An example of an illegal character is a double quote inside a string that is surrounded by double quotes:
#You will get an error if you use double quotes inside a string that is surrounded by double quotes:
 
txt = "we ara so-called \"vikings\" from the north."
print(txt)
we ara so-called "vikings" from the north.
 
txt = "we are so-called \"blackafrican\" from the south and north and west and east."
print(txt)
we are so-called "blackafrican" from the south and north and west and east.
 
#Python Booleans<>Booleans represent one of two values: True or False.
#Boolean Values In programming you often need to know if an expression is True or False.
#You can evaluate any expression in Python, and get one of two answers, True or False.
#When you compare two values, the expression is evaluated and Python returns the Boolean answer:
 
print(10 > 9)
print(10 == 9)
print(10 < 9)
True
False
False
 
print(50 > 40)
print(50 != 30)
print(50 < 40)
True
True
False
 
#When you run a condition in an if statement, Python returns True or False:
#Print a message based on whether the condition is True or False:
 
a = 200
b = 33
​
if b > a:
    print("b is greater than a")
    
else:
    print("b is not greater than a")
    
b is not greater than a
 
z = 1500
x = 100
​
if b > z:
    print("x is greater than z")
else:
    print("x is not greater than z")
x is not greater than z
